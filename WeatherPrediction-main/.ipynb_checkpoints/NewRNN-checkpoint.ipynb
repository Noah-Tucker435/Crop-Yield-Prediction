# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

df = pd.read_csv('WeatherData.csv', index_col='Date', parse_dates=True)

# Print the first 5 rows
print(df.head())

feature_cols = ['Htemp', 'Ltemp', 'Humidity', 'Pressure']
target_col = 'yield'

# Normalize the data
scaler = MinMaxScaler()
data = scaler.fit_transform(df.values)

# Split the data into training and testing sets
train_size = int(len(data) * 0.8)
train_data = data[:train_size]
test_data = data[train_size:]

window_size = 7
batch_size = 50

train_generator = tf.keras.preprocessing.sequence.TimeseriesGenerator(train_data, train_data[:, 4],
                                                                     length=window_size, batch_size=batch_size)
test_generator = tf.keras.preprocessing.sequence.TimeseriesGenerator(test_data, test_data[:, 4],
                                                                    length=window_size, batch_size=batch_size)

model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(128, input_shape=(window_size, 5), return_sequences=True),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(64, return_sequences=False),
    tf.keras.layers.Dense(1, activation=None)
])

model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(train_generator, epochs=50, validation_data=test_generator)

# Evaluate the model
loss = model.evaluate(test_generator)
print('Test Loss:', loss)

# Plot the loss over time
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# Predict the test data
test_predict = model.predict(test_generator)

# Transform the data back to its original scale
test_data_unscaled = scaler.inverse_transform(test_data)
test_predict_unscaled = scaler.inverse_transform(np.concatenate((test_data_unscaled[window_size:, :-1], test_predict), axis=1))[:, -1]
test_actual_unscaled = test_data_unscaled[window_size:, 4]

# Plot the predicted versus actual values
plt.figure(figsize=(10, 6))
plt.plot(test_actual_unscaled, label='Actual')
plt.plot(test_predict_unscaled, label='Predicted')
plt.title('Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Yield')
plt.legend()
plt.show()

# Display the final predicted value
final_actual = test_actual_unscaled[-1]
final_predicted = test_predict_unscaled[-1]
print(f"Final Actual = {final_actual}, Final Predicted = {final_predicted}")

# Compute the MAE
mae = mean_absolute_error([final_actual], [final_predicted])
print(f"Mean Absolute Error: {mae}")


# Load the weather data for next year
next_year_weather = pd.read_csv('NewData.csv', index_col='Date', parse_dates=True)

# Normalize the data using the same scaler as before
next_year_data = scaler.transform(next_year_weather.values)

# Create a time series generator for the new data
next_year_generator = tf.keras.preprocessing.sequence.TimeseriesGenerator(next_year_data, np.zeros(len(next_year_data)), 
                                                                           length=window_size, batch_size=batch_size)

# Use the trained LSTM model to make predictions on the new data
next_year_predict = model.predict(next_year_generator)

# Transform the predicted values back to their original scale
next_year_predict_unscaled = scaler.inverse_transform(np.concatenate((next_year_data[window_size:, :-1], next_year_predict), axis=1))[:, -1]

# Print the predicted yield for next year
print(f"Predicted yield for next year: {next_year_predict_unscaled[-1]}")
# Out:
#         Htemp  Ltemp  Humidity  Pressure  Yield
# Date
# 15-Feb     74     19        61     30.23   7340
# 15-Mar     84     17        72     30.16   7340
# 15-Apr     86     43        67     29.97   7340
# 15-May     87     50        70     30.07   7340
# 15-Jun     98     64        67     29.98   7340
# Epoch 1/50
# 2/2 [==============================] - 4s 969ms/step - loss: 0.4586 - val_loss: 0.2811
# Epoch 2/50
# 2/2 [==============================] - 0s 59ms/step - loss: 0.3211 - val_loss: 0.1668
# Epoch 3/50
# 2/2 [==============================] - 0s 59ms/step - loss: 0.2026 - val_loss: 0.0771
# Epoch 4/50
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1221 - val_loss: 0.0195
# Epoch 5/50
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0722 - val_loss: 0.0048
# Epoch 6/50
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0870 - val_loss: 0.0347
# Epoch 7/50
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1345 - val_loss: 0.0716
# Epoch 8/50
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1555 - val_loss: 0.0682
# Epoch 9/50
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1396 - val_loss: 0.0458
# Epoch 10/50
# 2/2 [==============================] - 0s 69ms/step - loss: 0.1175 - val_loss: 0.0228
# Epoch 11/50
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0802 - val_loss: 0.0100
# Epoch 12/50
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0749 - val_loss: 0.0041
# Epoch 13/50
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0644 - val_loss: 0.0034
# Epoch 14/50
# 2/2 [==============================] - 0s 88ms/step - loss: 0.0601 - val_loss: 0.0040
# Epoch 15/50
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0619 - val_loss: 0.0047
# Epoch 16/50
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0575 - val_loss: 0.0043
# Epoch 17/50
# 2/2 [==============================] - 0s 88ms/step - loss: 0.0583 - val_loss: 0.0037
# Epoch 18/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0576 - val_loss: 0.0038
# Epoch 19/50
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0588 - val_loss: 0.0051
# Epoch 20/50
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0573 - val_loss: 0.0069
# Epoch 21/50
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0600 - val_loss: 0.0096
# Epoch 22/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0608 - val_loss: 0.0106
# Epoch 23/50
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0611 - val_loss: 0.0119
# Epoch 24/50
# 2/2 [==============================] - 0s 69ms/step - loss: 0.0606 - val_loss: 0.0106
# Epoch 25/50
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0585 - val_loss: 0.0101
# Epoch 26/50
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0591 - val_loss: 0.0082
# Epoch 27/50
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0529 - val_loss: 0.0077
# Epoch 28/50
# 2/2 [==============================] - 0s 88ms/step - loss: 0.0493 - val_loss: 0.0074
# Epoch 29/50
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0518 - val_loss: 0.0070
# Epoch 30/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0463 - val_loss: 0.0071
# Epoch 31/50
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0477 - val_loss: 0.0075
# Epoch 32/50
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0473 - val_loss: 0.0086
# Epoch 33/50
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0451 - val_loss: 0.0097
# Epoch 34/50
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0490 - val_loss: 0.0108
# Epoch 35/50
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0473 - val_loss: 0.0106
# Epoch 36/50
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0478 - val_loss: 0.0106
# Epoch 37/50
# 2/2 [==============================] - 0s 70ms/step - loss: 0.0437 - val_loss: 0.0108
# Epoch 38/50
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0445 - val_loss: 0.0113
# Epoch 39/50
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0422 - val_loss: 0.0120
# Epoch 40/50
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0449 - val_loss: 0.0126
# Epoch 41/50
# 2/2 [==============================] - 0s 90ms/step - loss: 0.0434 - val_loss: 0.0140
# Epoch 42/50
# 2/2 [==============================] - 0s 89ms/step - loss: 0.0445 - val_loss: 0.0148
# Epoch 43/50
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0430 - val_loss: 0.0143
# Epoch 44/50
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0441 - val_loss: 0.0146
# Epoch 45/50
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0400 - val_loss: 0.0148
# Epoch 46/50
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0415 - val_loss: 0.0151
# Epoch 47/50
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0390 - val_loss: 0.0159
# Epoch 48/50
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0399 - val_loss: 0.0161
# Epoch 49/50
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0379 - val_loss: 0.0166
# Epoch 50/50
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0380 - val_loss: 0.0171
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0171
# Test Loss: 0.017090586945414543
# 1/1 [==============================] - 1s 1s/step
# Final Actual = 7410.0, Final Predicted = 7310.002121925355
# 1/1 [==============================] - 0s 45ms/step
# The predicted yield for next year is: 0.6234109
